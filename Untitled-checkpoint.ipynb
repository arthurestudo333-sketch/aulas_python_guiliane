# %%
# Aprendendo oque é uma variavel
idade = 44
print(idade)
# Out:
# 44

# %%
idade=30
print(idade)
# Out:
# 30

# %%
type(idade)
# Out:
# int

# %%
x = 3.45
type(x)
# Out:
# float

# %%
y = "Arthur"
type(y)
# Out:
# str

# %%
x = "3.45"
type(x)
# Out:
# str

# %%
#adição em python
a = 3
b = 4
c = a + b

# %%
c
# Out:
# 7

# %%
p = a * b
print(p)
# Out:
# 12

# %%
#subtração em python
s = a - b
r = b - a

# %%
idade = 20
maior_idade = idade >=18
print(maior_idade)
# Out:
# True

# %%
idade=17
maior_idade=idade >=18
print(maior_idade)
# Out:
# False

# %%
idade1=13
idade2=24
print(idade1==idade2)
# Out:
# False

# %%
idade2==18
# Out:
# False

# %%
idade2==24
# Out:
# False

# %%
login = "arthur"

# %%
login=="Carlos"
# Out:
# False

# %%
#comparar com !=
idade1 != idade2
# Out:
# True

# %%
idade1 != 13
# Out:
# False

# %%
num1= 3
num2= 44
num3= 55
num4= 6

print(num1>1)
print(num2<11)
print(num3>=110)
print(num4<=12)
# Out:
# True
# False
# False
# True
