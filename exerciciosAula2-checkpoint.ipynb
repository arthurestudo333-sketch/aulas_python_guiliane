# %%
print("Eu estou aprendendo python")
# Out:
# Eu estou aprendendo python

# %%
nome = "Meu nome é Maria"
local = "Eu moro em Recife"

# %%
nome + local
# Out:
# 'Meu nome é MariaEu moro em Recife'

# %%
del print

# %%
print(nome + " , " + local + " ")
# Out:
# Meu nome é Maria , Eu moro em Recife

# %%
nome_aluno = "Arthur"
idade_aluno =  "17"

# %%
print("Meu nome é:",nome_aluno,", " "Minha idade é:", idade_aluno)
# Out:
# Meu nome é: Arthur , Minha idade é: 17

# %%
cidade="Goiânia"
estado="Goias"
pais="Brasil"
print("Eu moro em:" + cidade + "," + estado + "," + pais)
# Out:
# Eu moro em:Goiânia,Goias,Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:

# %%
nome=input("Digite seu nome:")
local=input("Em qual cidade você mora?:")

print("Olá", nome + "," "Você mora em", local)
