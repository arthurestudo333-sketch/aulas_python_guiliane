# %% [markdown]
# Exercício 1
# Crie um programa que mostre na tela:

# %%
frase = "Eu estou aprendendo Python"
print(frase)
# Out:
# Eu estou aprendendo Python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
nome = "Meu nome é Maria"
local = "Eu moro em Recife"

print(nome)
print(local)
# Out:
# Meu nome é Maria
# Eu moro em Recife

# %% [markdown]
# Exercício 3
# Crie duas variáveis:

# %%
nome_do_aluno="Junior"
idade_do_aluno= 16

print("Meu nome é", nome_do_aluno + ",", "eu tenho", idade_do_aluno, "anos de idade")
# Out:
# Meu nome é Junior, eu tenho 16 anos de idade

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:

# %%
cidade= "Goiânia"
estado= "Goiás"
pais= "Brasil"

print("Eu moro em:", cidade,"-", estado,",",pais)
# Out:
# Eu moro em: Goiânia - Goiás , Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:

# %%
nome = input("Escreva seu nome:")
cidade = input("Em qual cidade você mora?:")
print("Olá", nome, "você mora em", cidade)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 nome= input("Escreva seu nome:")
#       2 cidade= input("Em qual cidade você mora?:")
#       3 print("Olá", nome, "você mora em", cidade)
#
# TypeError: 'str' object is not callable
